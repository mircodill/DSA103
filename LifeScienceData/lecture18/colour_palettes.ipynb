# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Sequential palettes
#
# Perceptionally uniform: colour difference mapped to difference in value (extreme values might be difficult to plot).

# %%
# Seaborn color palettes: "mako", "flare", "crest"; can be reversed by adding "_r"
sns.color_palette("rocket_r", as_cmap=True)

# %%
# Seaborn color palettes: "mako", "flare", "crest"; can be reversed by adding "_r"
sns.color_palette("flare", as_cmap=True)

# %%
# Seaborn cubehelix palettes
sns.cubehelix_palette(as_cmap=True)

# %%
# Matplotlib palettes: "viridis", "cividis", "magma"
sns.color_palette("magma", as_cmap=True)

# %%
# Custom cubehelix palette: 
# start = starting position in color wheel (0-3)
# rot = rotation of colour wheel = change of hues
# dark and light: darkest and lightest colours on the palette
sns.cubehelix_palette(start=.3, rot=1.4, dark=.3, light=0.8, n_colors=10)
# Out:
# [[0.9102941123085441, 0.7395072315694708, 0.8236602938111207],
#  [0.8441128595477478, 0.6773669764684942, 0.8383439112260664],
#  [0.7402476739213969, 0.635973781430515, 0.8445217907813555],
#  [0.610567793707752, 0.6138519869987203, 0.8177381565439434],
#  [0.4683706421510851, 0.6014665347203677, 0.7372193402322915],
#  [0.3585777134775464, 0.5867178746681022, 0.6166514026415002],
#  [0.2889110921289783, 0.5562836260256232, 0.47078011683829596],
#  [0.26356534827488187, 0.5030052269697275, 0.3265618654460851],
#  [0.27204567153569786, 0.4273583552801931, 0.21006754544158932],
#  [0.2942596404685361, 0.3305624008672179, 0.1339036210622576]]

# %% [markdown]
# ### Qualitative color palettes
#
# Qualitative palettes are well-suited to representing categorical data because most of their variation is in the hue component.

# %%
# Deafult palette in seaborn:
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# many other palettes available! Try different ones!
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
# circular pattern: evenly spaced hues in a circle, constant brightness and saturation.
# Perception by human eye: different intensity for different colours (RGB issue!)
sns.color_palette("hls", 10)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.6832, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.41279999999999994, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.4752000000000003, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6207999999999999)]

# %%
# Create a sequential palette with 8 colors
sns.color_palette("Blues", 8)
# Out:
# [(0.8825067281814687, 0.929196462898885, 0.9724413687043445),
#  (0.7993540945790081, 0.8740792003075739, 0.944882737408689),
#  (0.6718954248366014, 0.8143790849673203, 0.9006535947712418),
#  (0.5105882352941177, 0.7323029603998462, 0.8588389081122645),
#  (0.34646674356016915, 0.632402921953095, 0.8106728181468666),
#  (0.21568627450980393, 0.5294117647058824, 0.7542483660130719),
#  (0.10557477893118032, 0.41262591311034214, 0.6859669357939254),
#  (0.03137254901960784, 0.301914648212226, 0.588404459823145)]

# %% [markdown]
# ### Diverging palettes
# If extreme values are interesting and the middle is less so (e.g. correlation): Similar to sequential, but with two colours.

# %%
# Seaborn palettes: e.g. "vlag", "icefire"
sns.color_palette("vlag", as_cmap=True)

# %%
# Matplotlib palettes: e.g. "Spectral", "coolwarm"
sns.color_palette("coolwarm", as_cmap=True)

# %%
# Custom diverging palette, using the hus1 system: define two angles on colour wheel and saturation (s)
sns.diverging_palette(270, 180, s=70, as_cmap=True)
